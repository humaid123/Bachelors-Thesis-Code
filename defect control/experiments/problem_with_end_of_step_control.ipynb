# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from math import sin, sqrt, exp, cos

# %%
methods = ["RK45", "RK23", "DOP853",] # can also add RK23, DOP853, Radau, BDF, LSODA
t_eval = np.array([ x for x in range(0, 100) ]) / 10
tolerances =  [1e-6]

# %%
def experiment(model, y0, t_span, solution):
    for method in methods:
        for tol in tolerances:
            atol = tol
            rtol = tol
            dense = solve_ivp(model, t_span, y0, method=method, atol=atol, rtol=rtol, dense_output=True)
            sol = solution(t_eval)
            computed = dense.sol(t_eval)
            abs_err = np.abs(computed[0] - sol)
            rel_err = [ abs(abs_err[i] / computed[0][i])  for i in range(len(t_eval)) ]
        
            plt.figure()
            plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
            for t in dense.t: plt.axvline(x=t)
            # plt.axhline(y=np.log10(atol), label="abs tol", color="g")
            plt.title(f"{method} at atol of {atol}")
            plt.legend()
            plt.show()


            plt.figure()
            plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
            for t in dense.t: plt.axvline(x=t)
            # plt.axhline(y=np.log10(rtol), label="rel tol", color="g")
            plt.title(f"{method} at rtol of {rtol}")
            plt.legend()
            plt.show()

            print(f"used {dense.nfev} function evaluations, {dense.njev} Jacobian evaluations. {dense.nlu} LU decompositions. {len(dense.t)} steps")

# %%
t_span_1 = [0, 10]
y0_1 = [1]

def model1(t, y):
    return [(-1/2) * y**3]

def solution1(t):
    return [1/sqrt(1+x) for x in t]

experiment(model1, y0_1, t_span_1, solution1)
# Out:
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 80 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 14 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 206 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 69 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 122 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 9 steps

# %%
t_span_2 = [0, 1]
y0_2 = [1]

def model2(t, y):
    return [-2*t*y**2]

def solution2(t):
    return [1/(1+x**2) for x in t]

experiment(model2, y0_2, t_span_2, solution2)
# Out:
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# used 68 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 10 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 119 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 37 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 119 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 8 steps

# %%
t_span_3 = [0, 10]
y0_3 = [1]

def model3(t, y):
    return [(1/4)*y*(1 - y/20)]

def solution3(t):
    return [20 / ( 1 + 19 * exp(-x/4) ) for x in t]

experiment(model3, y0_3, t_span_3, solution3)
# Out:
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 56 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 10 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 143 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 46 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 62 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 5 steps

# %%
t_span_4 = [0, 10]
y0_4 = [0]

def model4(t, y):
    # return [100 * (sin(t) - y)]
    return [10 * (sin(t) - y)]

def solution4(t):
    # return [( 100 * ( exp(-100 * x) - cos(x) ) +  10000 * sin(x) ) / 10001 for x in t]
    return [( 10 * ( exp(-10 * x) - cos(x) ) +  100 * sin(x) ) / 101 for x in t]

experiment(model4, y0_4, t_span_4, solution4)
# Out:
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   rel_err = [ abs(abs_err[i] / computed[0][i])  for i in range(len(t_eval)) ]
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# used 902 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 147 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   rel_err = [ abs(abs_err[i] / computed[0][i])  for i in range(len(t_eval)) ]
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# used 935 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 305 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   rel_err = [ abs(abs_err[i] / computed[0][i])  for i in range(len(t_eval)) ]
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# used 1043 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 68 steps

# %%
t_span_5 = [0, 10]
y0_5 = [2]

def model5(t, y):
    return [(15 * cos(10 * t))/y]

def solution5(t):
    return [sqrt(3*sin(10*x) + 4) for x in t]

experiment(model5, y0_5, t_span_5, solution5)
# Out:
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 1544 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 209 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 5312 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 1721 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 2456 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 123 steps

# %%
t_span_6 = [0, 10]
y0_6 = [1]

def model6(t, y):
    return [-y/(t+1)]

def solution6(t):
    return [1/(x+1) for x in t]

experiment(model6, y0_6, t_span_6, solution6)
# Out:
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 74 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 13 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 260 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 87 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 137 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 10 steps

# %%
t_span_7 = [0, 10]
y0_7 = [1]

def model7(t, y):
    alpha = 0.1
    return [ -alpha*y - exp(-alpha*t)*sin(t)]

def solution7(t):
    alpha = 0.1
    return [exp(-alpha*x)*cos(x) for x in t]

experiment(model7, y0_7, t_span_7, solution7)
# Out:
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 134 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 18 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 614 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 199 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 134 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 9 steps

# %%
# Jeff cash test set first one

t_span_8 = [0, 10]
eps = 0.1
a = exp(-1/eps)
y0_8 = [1, a/(eps*(-1+a))]

def model8(t, y):
    return [y[1], y[0]/eps]

def solution8(t):
    # THE experiment method calculates error on "computed[0]"
    # so we can only verify the error of y[0] there
    return [(1-exp(x/eps)*a)/(1-a) for x in t]

experiment(model8, y0_8, t_span_8, solution8)

## the results were extremely bad. So i wanted to see the solution
plt.figure()
plt.plot(t_span_8, solution8(t_span_8))
# Out:
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 758 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 127 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 2897 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 966 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 392 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 27 steps

# %%
# Jeff cash test set second one
t_span_9 = [0, 10]
eps = 0.1
y0_9 = [1, -1/sqrt(eps)]

def model9(t, y):
    return [y[1], (y[0] + y[0]**2 - exp(-2*t/sqrt(eps)))/eps]

def solution9(t):
    # THE experiment method calculates error on "computed[0]"
    # so we can only verify the error of y[0] there
    return [exp(-x/sqrt(eps)) for x in t]

experiment(model9, y0_9, t_span_9, solution9)
# Out:
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 524 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 79 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 1370 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 455 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 476 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 27 steps

# %%
# Wolfram Alpha first problem

t_span_10 = [0, 10]
y0_10 = [1, 2]

def model10(t, y):
    return [y[1], -3*y[0] + 2*cos(4*t)]

def solution10(t):
    # THE experiment method calculates error on "computed[0]"
    # so we can only verify the error of y[0] there
    s = sqrt(3)
    return [(26*s*sin(s*x) - 6*cos(4*x) + 45*cos(s*x))/39 for x in t]

experiment(model10, y0_10, t_span_10, solution10)
# Out:
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 470 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 75 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 1886 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 620 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 407 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 28 steps

# %%
t_span_11 = [0, 10]
y0_11 = [1]

def model11(t, y):
    return [-2*y[0] + t]

def solution11(t):
    return [1/4 * (-1 + 5 * exp(-2 * x) + 2 * x) for x in t]

experiment(model11, y0_11, t_span_11, solution11)
# Out:
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 158 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 27 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 269 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 88 steps
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(abs_err), label="abs err", color="r")
# C:\Users\huago\AppData\Local\Temp/ipykernel_9584/3099866370.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(t_eval, np.log10(rel_err), label="rel err", color="r")
# used 167 function evaluations, 0 Jacobian evaluations. 0 LU decompositions. 12 steps
